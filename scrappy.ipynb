# %%
from bs4 import BeautifulSoup
import requests

datas = requests.get("https:/www.cyclobold.com/')
# Out:
#   Cell In[4], line 4
#     datas = requests.get("https:/www.cyclobold.com/')
#                          ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
import requests
from bs4 import BeautifulSoup
datas = requests.get("https://www.cyclobold.com/")
feeds = BeautifulSoup(datas.content,"html.parser")
html_template = feeds.prettify()
print(html_template)
# print(datas.headers)
# print(datas.cookies)
# print(datas.content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="default-src 'self' 'unsafe-inline' data: https: *.crazyegg.com; frame-src *.mobilemonkey.com *.facebook.com;" http-equiv="Content-Security-Policy"/>
#   <!-- Facebook Domain Verification -->
#   <meta content="44ycdu0zt8tczlzb3esqk211rw6jwq" name="facebook-domain-verification">
#    <!-- End of Facebook Domain Verification -->
#    <meta charset="utf-8"/>
#    <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#    <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#    <meta content="Cyclobold Technology Academy" name="author"/>
#    <meta content="I1oRUDdwLOhVH9dRcucUQ5IfsXHr9SvodEBgY8ZF" name="csrf-token">
#     <!-- Start of cyclobold Zendesk Widget script -->
#     <!-- End of cyclobold Zendesk Widget script -->
#     <!-- Page Meta Title -->
#     <title>
#      Learn Software Engineering and Coding | Cyclobold
#     </title>
#     <!-- Google Tag Manager -->
#     <script>
# ...

# %%
print(feeds.findAll("p"))
# Out:
# [<p>We teach hard concepts in ways that can be easily understood. Our classes are very interactive and problem-solving driven.</p>, <p>We thoroughly prepare our students, not just for a job but a fulfilling career in software engineering.</p>, <p>
#                           Our approach is simple, yet gives you the opportunity to master software engineering in the least amount of time:
#
#                            <ul>
# <strong>
# <li>More than 100 hours of Video Tutorials </li>
# <li>100% In depth Practical Sessions</li>
# <li>Logbooks and Workbooks</li>
# <li>Project-based sessions</li>
# <li>Access to Seminars and Workshops</li>
# <li>Access to Groups and Channels</li>
# </strong>
# </ul>
# ...
